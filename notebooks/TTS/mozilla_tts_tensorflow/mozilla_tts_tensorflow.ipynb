# %% [markdown]
# # Converting Pytorch models to Tensorflow and TFLite by 🐸 [Coqui TTS](https://github.com/coqui-ai/TTS)

# %% [markdown]
# This is a tutorial demonstrating 🐸 TTS capabilities to convert
#
# > Indented block
#
#
# trained PyTorch models to Tensorflow and Tflite.

# %% [markdown]
# # Installation

# %% [markdown]
# ### Download TF Models and configs

# %%
# !gdown --id 1dntzjWFg7ufWaTaFy80nRz-Tu02xWZos -O tts_model.pth.tar
# !gdown --id 18CQ6G6tBEOfvCHlPqP8EBI4xWbrr9dBc -O config.json
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/gdown/cli.py:126: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (uriginal): https://drive.google.com/uc?id=1dntzjWFg7ufWaTaFy80nRz-Tu02xWZos
# From (redirected): https://drive.google.com/uc?id=1dntzjWFg7ufWaTaFy80nRz-Tu02xWZos&confirm=t&uuid=e21ebc94-0065-4018-b4cf-efd723865d39
# To: /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/tts_model.pth.tar
# 100%|████████████████████████████████████████| 347M/347M [00:12<00:00, 28.7MB/s]
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/gdown/cli.py:126: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=18CQ6G6tBEOfvCHlPqP8EBI4xWbrr9dBc
# To: /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/config.json
# 100%|██████████████████████████████████████| 9.53k/9.53k [00:00<00:00, 18.2MB/s]

# %%
# !gdown --id 1Ty5DZdOc0F7OTGj9oJThYbL5iVu_2G0K -O vocoder_model.pth.tar
# !gdown --id 1Rd0R_nRCrbjEdpOwq6XwZAktvugiBvmu -O config_vocoder.json
# !gdown --id 11oY3Tv0kQtxK_JPgxrfesa99maVXHNxU -O scale_stats.npy
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/gdown/cli.py:126: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1Ty5DZdOc0F7OTGj9oJThYbL5iVu_2G0K
# To: /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/vocoder_model.pth.tar
# 100%|██████████████████████████████████████| 82.8M/82.8M [00:02<00:00, 33.6MB/s]
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/gdown/cli.py:126: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1Rd0R_nRCrbjEdpOwq6XwZAktvugiBvmu
# To: /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/config_vocoder.json
# 100%|██████████████████████████████████████| 6.76k/6.76k [00:00<00:00, 11.3MB/s]
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/gdown/cli.py:126: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=11oY3Tv0kQtxK_JPgxrfesa99maVXHNxU
# To: /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/scale_stats.npy
# 100%|██████████████████████████████████████| 10.5k/10.5k [00:00<00:00, 18.3MB/s]

# %% [markdown]
# ### Setup Libraries

# %%
# need it for char to phoneme conversion
! sudo apt-get install espeak
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-440
# Use 'sudo apt autoremove' to remove it.
# The following additional packages will be installed:
#   espeak-data libespeak1 libportaudio2 libsonic0
# The following NEW packages will be installed:
#   espeak espeak-data libespeak1 libportaudio2 libsonic0
# 0 upgraded, 5 newly installed, 0 to remove and 35 not upgraded.
# Need to get 1,219 kB of archives.
# After this operation, 3,031 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libportaudio2 amd64 19.6.0-1 [64.6 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/main amd64 libsonic0 amd64 0.2.0-6 [13.4 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/universe amd64 espeak-data amd64 1.48.04+dfsg-5 [934 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libespeak1 amd64 1.48.04+dfsg-5 [145 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic/universe amd64 espeak amd64 1.48.04+dfsg-5 [61.6 kB]
# Fetched 1,219 kB in 1s (1,465 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 5.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package libportaudio2:amd64.
# (Reading database ... 144465 files and directories currently installed.)
# Preparing to unpack .../libportaudio2_19.6.0-1_amd64.deb ...
# Unpacking libportaudio2:amd64 (19.6.0-1) ...
# Selecting previously unselected package libsonic0:amd64.
# Preparing to unpack .../libsonic0_0.2.0-6_amd64.deb ...
# Unpacking libsonic0:amd64 (0.2.0-6) ...
# Selecting previously unselected package espeak-data:amd64.
# Preparing to unpack .../espeak-data_1.48.04+dfsg-5_amd64.deb ...
# Unpacking espeak-data:amd64 (1.48.04+dfsg-5) ...
# Selecting previously unselected package libespeak1:amd64.
# Preparing to unpack .../libespeak1_1.48.04+dfsg-5_amd64.deb ...
# Unpacking libespeak1:amd64 (1.48.04+dfsg-5) ...
# Selecting previously unselected package espeak.
# Preparing to unpack .../espeak_1.48.04+dfsg-5_amd64.deb ...
# Unpacking espeak (1.48.04+dfsg-5) ...
# Setting up libportaudio2:amd64 (19.6.0-1) ...
# Setting up espeak-data:amd64 (1.48.04+dfsg-5) ...
# Setting up libsonic0:amd64 (0.2.0-6) ...
# Setting up libespeak1:amd64 (1.48.04+dfsg-5) ...
# Setting up espeak (1.48.04+dfsg-5) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.6/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link

# %%
# !git clone https://github.com/coqui-ai/TTS
# Out:
# Cloning into 'TTS'...
# remote: Enumerating objects: 32400, done.
# remote: Counting objects: 100% (5031/5031), done.
# remote: Compressing objects: 100% (792/792), done.
# remote: Total 32400 (delta 4602), reused 4348 (delta 4220), pack-reused 27369
# Receiving objects: 100% (32400/32400), 166.10 MiB | 9.43 MiB/s, done.
# Resolving deltas: 100% (23520/23520), done.

# %%
# %cd TTS
# !git checkout dev
# !pip install -r requirements.txt
# !python setup.py develop
# !pip install tensorflow==2.3.0rc0
# %cd ..
# Out:
# /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/TTS
# /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]
# Already on 'dev'
# Your branch is up to date with 'origin/dev'.
# DEPRECATION: Loading egg at /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages/attrdict-2.0.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages/TTS-0.0.3+c7296b3-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages/Unidecode-0.04.20-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages/librosa-0.6.2-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages/resampy-0.4.2-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# Ignoring numpy: markers 'python_version <= "3.10"' don't match your environment
# Ignoring numba: markers 'python_version < "3.9"' don't match your environment
# Requirement already satisfied: numpy>=1.24.3 in /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from -r requirements.txt (line 3)) (1.26.2)
# Collecting cython>=0.29.30 (from -r requirements.txt (line 4))
#   Downloading Cython-3.0.6-cp311-cp311-macosx_10_9_x86_64.whl.metadata (3.2 kB)
# Requirement already satisfied: scipy>=1.11.2 in /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from -r requirements.txt (line 5)) (1.11.4)
# Requirement already satisfied: torch>=2.1 in /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from -r requirements.txt (line 6)) (2.1.1)
# Collecting torchaudio (from -r requirements.txt (line 7))
#   Downloading torchaudio-2.1.1-cp311-cp311-macosx_10_13_x86_64.whl.metadata (6.4 kB)
# Requirement already satisfied: soundfile>=0.12.0 in /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from -r requirements.txt (line 8)) (0.12.1)
# Collecting librosa>=0.10.0 (from -r requirements.txt (line 9))
#   Downloading librosa-0.10.1-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: scikit-learn>=1.3.0 in /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from -r requirements.txt (line 10)) (1.3.2)
# Requirement already satisfied: numba>=0.57.0 in /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from -r requirements.txt (line 12)) (0.58.1)
# Requirement already satisfied: inflect>=5.6.0 in /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from -r requirements.txt (line 13)) (7.0.0)
# Requirement already satisfied: tqdm>=4.64.1 in /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from -r requirements.txt (line 14)) (4.66.1)
# Collecting anyascii>=0.3.0 (from -r requirements.txt (line 15))
#   Downloading anyascii-0.3.2-py3-none-any.whl (289 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 289.9/289.9 kB 2.2 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: pyyaml>=6.0 in /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from -r requirements.txt (line 16)) (6.0.1)
# Requirement already satisfied: fsspec>=2023.6.0 in /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from -r requirements.txt (line 17)) (2023.10.0)
# Collecting aiohttp>=3.8.1 (from -r requirements.txt (line 18))
#   Downloading aiohttp-3.9.1-cp311-cp311-macosx_10_9_x86_64.whl.metadata (7.4 kB)
# Requirement already satisfied: packaging>=23.1 in /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from -r requirements.txt (line 19)) (23.2)
# Requirement already satisfied: flask>=2.0.1 in /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from -r requirements.txt (line 21)) (3.0.0)
# Collecting pysbd>=0.3.4 (from -r requirements.txt (line 23))
#   Downloading pysbd-0.3.4-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.1/71.1 kB 1.6 MB/s eta 0:00:00a 0:00:01
# Collecting umap-learn>=0.5.1 (from -r requirements.txt (line 25))
#   Downloading umap-learn-0.5.5.tar.gz (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.9/90.9 kB 2.0 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# Collecting pandas<2.0,>=1.4 (from -r requirements.txt (line 26))
#   Downloading pandas-1.5.3-cp311-cp311-macosx_10_9_x86_64.whl (11.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.9/11.9 MB 6.6 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: matplotlib>=3.7.0 in /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from -r requirements.txt (line 28)) (3.8.2)
# Collecting trainer>=0.0.32 (from -r requirements.txt (line 30))
#   Downloading trainer-0.0.32-py3-none-any.whl.metadata (8.1 kB)
# Collecting coqpit>=0.0.16 (from -r requirements.txt (line 32))
#   Downloading coqpit-0.0.17-py3-none-any.whl (13 kB)
# Collecting jieba (from -r requirements.txt (line 34))
#   Downloading jieba-0.42.1.tar.gz (19.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.2/19.2 MB 8.3 MB/s eta 0:00:0000:0100:01m
#   Preparing metadata (setup.py) ... done
# Collecting pypinyin (from -r requirements.txt (line 35))
#   Downloading pypinyin-0.49.0-py2.py3-none-any.whl.metadata (12 kB)
# Collecting hangul_romanize (from -r requirements.txt (line 37))
#   Downloading hangul_romanize-0.1.0-py3-none-any.whl (4.6 kB)
# Collecting gruut==2.2.3 (from gruut[de,es,fr]==2.2.3->-r requirements.txt (line 39))
#   Downloading gruut-2.2.3.tar.gz (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.5/73.5 kB 4.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting jamo (from -r requirements.txt (line 41))
#   Downloading jamo-0.4.1-py3-none-any.whl (9.5 kB)
# Collecting nltk (from -r requirements.txt (line 42))
#   Downloading nltk-3.8.1-py3-none-any.whl (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 6.4 MB/s eta 0:00:0000:0100:01
# Collecting g2pkk>=0.1.1 (from -r requirements.txt (line 43))
#   Downloading g2pkk-0.1.2-py3-none-any.whl (25 kB)
# Collecting bangla (from -r requirements.txt (line 45))
#   Downloading bangla-0.0.2-py2.py3-none-any.whl (6.2 kB)
# Collecting bnnumerizer (from -r requirements.txt (line 46))
#   Downloading bnnumerizer-0.0.2.tar.gz (4.7 kB)
#   Preparing metadata (setup.py) ... done
# Collecting bnunicodenormalizer (from -r requirements.txt (line 47))
#   Downloading bnunicodenormalizer-0.1.6.tar.gz (39 kB)
#   Preparing metadata (setup.py) ... done
# Collecting einops>=0.6.0 (from -r requirements.txt (line 49))
#   Downloading einops-0.7.0-py3-none-any.whl.metadata (13 kB)
# Collecting transformers>=4.33.0 (from -r requirements.txt (line 50))
#   Downloading transformers-4.35.2-py3-none-any.whl.metadata (123 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.5/123.5 kB 4.6 MB/s eta 0:00:00
# Collecting encodec>=0.1.1 (from -r requirements.txt (line 52))
#   Downloading encodec-0.1.1.tar.gz (3.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 6.1 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# Collecting unidecode>=1.3.2 (from -r requirements.txt (line 54))
#   Downloading Unidecode-1.3.7-py3-none-any.whl.metadata (13 kB)
# Collecting num2words (from -r requirements.txt (line 55))
#   Downloading num2words-0.5.13-py3-none-any.whl.metadata (12 kB)
# Collecting spacy>=3 (from spacy[ja]>=3->-r requirements.txt (line 56))
#   Downloading spacy-3.7.2-cp311-cp311-macosx_10_9_x86_64.whl.metadata (25 kB)
# Requirement already satisfied: Babel<3.0.0,>=2.8.0 in /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from gruut==2.2.3->gruut[de,es,fr]==2.2.3->-r requirements.txt (line 39)) (2.13.1)
# Collecting dateparser~=1.1.0 (from gruut==2.2.3->gruut[de,es,fr]==2.2.3->-r requirements.txt (line 39))
#   Downloading dateparser-1.1.8-py2.py3-none-any.whl (293 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.8/293.8 kB 2.3 MB/s eta 0:00:0000:0100:01
# Collecting gruut-ipa<1.0,>=0.12.0 (from gruut==2.2.3->gruut[de,es,fr]==2.2.3->-r requirements.txt (line 39))
#   Downloading gruut-ipa-0.13.0.tar.gz (101 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.6/101.6 kB 2.2 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# Collecting gruut_lang_en~=2.0.0 (from gruut==2.2.3->gruut[de,es,fr]==2.2.3->-r requirements.txt (line 39))
#   Downloading gruut_lang_en-2.0.0.tar.gz (15.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.2/15.2 MB 7.6 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# Collecting jsonlines~=1.2.0 (from gruut==2.2.3->gruut[de,es,fr]==2.2.3->-r requirements.txt (line 39))
#   Downloading jsonlines-1.2.0-py2.py3-none-any.whl (7.6 kB)
# Collecting networkx<3.0.0,>=2.5.0 (from gruut==2.2.3->gruut[de,es,fr]==2.2.3->-r requirements.txt (line 39))
#   Downloading networkx-2.8.8-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 7.9 MB/s eta 0:00:00a 0:00:01
# Collecting python-crfsuite~=0.9.7 (from gruut==2.2.3->gruut[de,es,fr]==2.2.3->-r requirements.txt (line 39))
#   Downloading python_crfsuite-0.9.9-cp311-cp311-macosx_10_9_x86_64.whl (180 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.9/180.9 kB 6.4 MB/s eta 0:00:00
# Collecting gruut_lang_de~=2.0.0 (from gruut[de,es,fr]==2.2.3->-r requirements.txt (line 39))
#   Downloading gruut_lang_de-2.0.0.tar.gz (18.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.1/18.1 MB 4.3 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# Collecting gruut_lang_es~=2.0.0 (from gruut[de,es,fr]==2.2.3->-r requirements.txt (line 39))
#   Downloading gruut_lang_es-2.0.0.tar.gz (31.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.4/31.4 MB 7.8 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# Collecting gruut_lang_fr~=2.0.0 (from gruut[de,es,fr]==2.2.3->-r requirements.txt (line 39))
#   Downloading gruut_lang_fr-2.0.2.tar.gz (10.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 8.8 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: filelock in /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from torch>=2.1->-r requirements.txt (line 6)) (3.13.1)
# Requirement already satisfied: typing-extensions in /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from torch>=2.1->-r requirements.txt (line 6)) (4.8.0)
# Requirement already satisfied: sympy in /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from torch>=2.1->-r requirements.txt (line 6)) (1.12)
# Requirement already satisfied: jinja2 in /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from torch>=2.1->-r requirements.txt (line 6)) (3.1.2)
# Requirement already satisfied: cffi>=1.0 in /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from soundfile>=0.12.0->-r requirements.txt (line 8)) (1.16.0)
# Requirement already satisfied: audioread>=2.1.9 in /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from librosa>=0.10.0->-r requirements.txt (line 9)) (3.0.1)
# Requirement already satisfied: joblib>=0.14 in /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from librosa>=0.10.0->-r requirements.txt (line 9)) (1.3.2)
# Requirement already satisfied: decorator>=4.3.0 in /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from librosa>=0.10.0->-r requirements.txt (line 9)) (5.1.1)
# Requirement already satisfied: pooch>=1.0 in /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from librosa>=0.10.0->-r requirements.txt (line 9)) (1.8.0)
# Requirement already satisfied: soxr>=0.3.2 in /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from librosa>=0.10.0->-r requirements.txt (line 9)) (0.3.7)
# Requirement already satisfied: lazy-loader>=0.1 in /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from librosa>=0.10.0->-r requirements.txt (line 9)) (0.3)
# Requirement already satisfied: msgpack>=1.0 in /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from librosa>=0.10.0->-r requirements.txt (line 9)) (1.0.7)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from scikit-learn>=1.3.0->-r requirements.txt (line 10)) (3.2.0)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from numba>=0.57.0->-r requirements.txt (line 12)) (0.41.1)
# Requirement already satisfied: pydantic>=1.9.1 in /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from inflect>=5.6.0->-r requirements.txt (line 13)) (2.5.2)
# Requirement already satisfied: attrs>=17.3.0 in /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from aiohttp>=3.8.1->-r requirements.txt (line 18)) (23.1.0)
# Collecting multidict<7.0,>=4.5 (from aiohttp>=3.8.1->-r requirements.txt (line 18))
#   Downloading multidict-6.0.4-cp311-cp311-macosx_10_9_x86_64.whl (29 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp>=3.8.1->-r requirements.txt (line 18))
#   Downloading yarl-1.9.3-cp311-cp311-macosx_10_9_x86_64.whl.metadata (28 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp>=3.8.1->-r requirements.txt (line 18))
#   Downloading frozenlist-1.4.0-cp311-cp311-macosx_10_9_x86_64.whl.metadata (5.2 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp>=3.8.1->-r requirements.txt (line 18))
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: Werkzeug>=3.0.0 in /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from flask>=2.0.1->-r requirements.txt (line 21)) (3.0.1)
# Requirement already satisfied: itsdangerous>=2.1.2 in /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from flask>=2.0.1->-r requirements.txt (line 21)) (2.1.2)
# Requirement already satisfied: click>=8.1.3 in /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from flask>=2.0.1->-r requirements.txt (line 21)) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from flask>=2.0.1->-r requirements.txt (line 21)) (1.7.0)
# Collecting pynndescent>=0.5 (from umap-learn>=0.5.1->-r requirements.txt (line 25))
#   Downloading pynndescent-0.5.11-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from pandas<2.0,>=1.4->-r requirements.txt (line 26)) (2.8.2)
# Collecting pytz>=2020.1 (from pandas<2.0,>=1.4->-r requirements.txt (line 26))
#   Downloading pytz-2023.3.post1-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from matplotlib>=3.7.0->-r requirements.txt (line 28)) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from matplotlib>=3.7.0->-r requirements.txt (line 28)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from matplotlib>=3.7.0->-r requirements.txt (line 28)) (4.45.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from matplotlib>=3.7.0->-r requirements.txt (line 28)) (1.4.5)
# Requirement already satisfied: pillow>=8 in /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from matplotlib>=3.7.0->-r requirements.txt (line 28)) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from matplotlib>=3.7.0->-r requirements.txt (line 28)) (3.1.1)
# Requirement already satisfied: psutil in /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from trainer>=0.0.32->-r requirements.txt (line 30)) (5.9.6)
# Requirement already satisfied: tensorboard in /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from trainer>=0.0.32->-r requirements.txt (line 30)) (2.15.1)
# Requirement already satisfied: regex>=2021.8.3 in /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from nltk->-r requirements.txt (line 42)) (2023.10.3)
# Collecting huggingface-hub<1.0,>=0.16.4 (from transformers>=4.33.0->-r requirements.txt (line 50))
#   Downloading huggingface_hub-0.19.4-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: requests in /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from transformers>=4.33.0->-r requirements.txt (line 50)) (2.31.0)
# Collecting tokenizers<0.19,>=0.14 (from transformers>=4.33.0->-r requirements.txt (line 50))
#   Downloading tokenizers-0.15.0-cp311-cp311-macosx_10_7_x86_64.whl.metadata (6.7 kB)
# Collecting safetensors>=0.3.1 (from transformers>=4.33.0->-r requirements.txt (line 50))
#   Downloading safetensors-0.4.0-cp311-cp311-macosx_10_7_x86_64.whl.metadata (3.8 kB)
# Collecting docopt>=0.6.2 (from num2words->-r requirements.txt (line 55))
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Collecting spacy-legacy<3.1.0,>=3.0.11 (from spacy>=3->spacy[ja]>=3->-r requirements.txt (line 56))
#   Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0 (from spacy>=3->spacy[ja]>=3->-r requirements.txt (line 56))
#   Downloading spacy_loggers-1.0.5-py3-none-any.whl.metadata (23 kB)
# Collecting murmurhash<1.1.0,>=0.28.0 (from spacy>=3->spacy[ja]>=3->-r requirements.txt (line 56))
#   Downloading murmurhash-1.0.10-cp311-cp311-macosx_10_9_x86_64.whl.metadata (2.0 kB)
# Collecting cymem<2.1.0,>=2.0.2 (from spacy>=3->spacy[ja]>=3->-r requirements.txt (line 56))
#   Downloading cymem-2.0.8-cp311-cp311-macosx_10_9_x86_64.whl.metadata (8.4 kB)
# Collecting preshed<3.1.0,>=3.0.2 (from spacy>=3->spacy[ja]>=3->-r requirements.txt (line 56))
#   Downloading preshed-3.0.9-cp311-cp311-macosx_10_9_x86_64.whl.metadata (2.2 kB)
# Collecting thinc<8.3.0,>=8.1.8 (from spacy>=3->spacy[ja]>=3->-r requirements.txt (line 56))
#   Downloading thinc-8.2.1-cp311-cp311-macosx_10_9_x86_64.whl.metadata (15 kB)
# Collecting wasabi<1.2.0,>=0.9.1 (from spacy>=3->spacy[ja]>=3->-r requirements.txt (line 56))
#   Downloading wasabi-1.1.2-py3-none-any.whl.metadata (28 kB)
# Collecting srsly<3.0.0,>=2.4.3 (from spacy>=3->spacy[ja]>=3->-r requirements.txt (line 56))
#   Downloading srsly-2.4.8-cp311-cp311-macosx_10_9_x86_64.whl.metadata (20 kB)
# Collecting catalogue<2.1.0,>=2.0.6 (from spacy>=3->spacy[ja]>=3->-r requirements.txt (line 56))
#   Downloading catalogue-2.0.10-py3-none-any.whl.metadata (14 kB)
# Collecting weasel<0.4.0,>=0.1.0 (from spacy>=3->spacy[ja]>=3->-r requirements.txt (line 56))
#   Downloading weasel-0.3.4-py3-none-any.whl.metadata (4.7 kB)
# Collecting typer<0.10.0,>=0.3.0 (from spacy>=3->spacy[ja]>=3->-r requirements.txt (line 56))
#   Downloading typer-0.9.0-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.9/45.9 kB 3.9 MB/s eta 0:00:00
# Collecting smart-open<7.0.0,>=5.2.1 (from spacy>=3->spacy[ja]>=3->-r requirements.txt (line 56))
#   Downloading smart_open-6.4.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: setuptools in /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from spacy>=3->spacy[ja]>=3->-r requirements.txt (line 56)) (68.2.0)
# Collecting langcodes<4.0.0,>=3.2.0 (from spacy>=3->spacy[ja]>=3->-r requirements.txt (line 56))
#   Downloading langcodes-3.3.0-py3-none-any.whl (181 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.6/181.6 kB 7.9 MB/s eta 0:00:00
# Collecting sudachipy!=0.6.1,>=0.5.2 (from spacy[ja]>=3->-r requirements.txt (line 56))
#   Downloading SudachiPy-0.6.7-cp311-cp311-macosx_10_12_universal2.whl (2.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 10.9 MB/s eta 0:00:0000:0100:01
# Collecting sudachidict-core>=20211220 (from spacy[ja]>=3->-r requirements.txt (line 56))
#   Downloading SudachiDict_core-20230927-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: pycparser in /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from cffi>=1.0->soundfile>=0.12.0->-r requirements.txt (line 8)) (2.21)
# Collecting tzlocal (from dateparser~=1.1.0->gruut==2.2.3->gruut[de,es,fr]==2.2.3->-r requirements.txt (line 39))
#   Downloading tzlocal-5.2-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from jinja2->torch>=2.1->-r requirements.txt (line 6)) (2.1.3)
# Requirement already satisfied: six in /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from jsonlines~=1.2.0->gruut==2.2.3->gruut[de,es,fr]==2.2.3->-r requirements.txt (line 39)) (1.16.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from pooch>=1.0->librosa>=0.10.0->-r requirements.txt (line 9)) (4.0.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from pydantic>=1.9.1->inflect>=5.6.0->-r requirements.txt (line 13)) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.5 in /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from pydantic>=1.9.1->inflect>=5.6.0->-r requirements.txt (line 13)) (2.14.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from requests->transformers>=4.33.0->-r requirements.txt (line 50)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from requests->transformers>=4.33.0->-r requirements.txt (line 50)) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from requests->transformers>=4.33.0->-r requirements.txt (line 50)) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from requests->transformers>=4.33.0->-r requirements.txt (line 50)) (2023.11.17)
# Collecting blis<0.8.0,>=0.7.8 (from thinc<8.3.0,>=8.1.8->spacy>=3->spacy[ja]>=3->-r requirements.txt (line 56))
#   Downloading blis-0.7.11-cp311-cp311-macosx_10_9_x86_64.whl.metadata (7.4 kB)
# Collecting confection<1.0.0,>=0.0.1 (from thinc<8.3.0,>=8.1.8->spacy>=3->spacy[ja]>=3->-r requirements.txt (line 56))
#   Downloading confection-0.1.4-py3-none-any.whl.metadata (19 kB)
# Collecting cloudpathlib<0.17.0,>=0.7.0 (from weasel<0.4.0,>=0.1.0->spacy>=3->spacy[ja]>=3->-r requirements.txt (line 56))
#   Downloading cloudpathlib-0.16.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: mpmath>=0.19 in /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from sympy->torch>=2.1->-r requirements.txt (line 6)) (1.3.0)
# Requirement already satisfied: absl-py>=0.4 in /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from tensorboard->trainer>=0.0.32->-r requirements.txt (line 30)) (2.0.0)
# Requirement already satisfied: grpcio>=1.48.2 in /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from tensorboard->trainer>=0.0.32->-r requirements.txt (line 30)) (1.59.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from tensorboard->trainer>=0.0.32->-r requirements.txt (line 30)) (2.23.4)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from tensorboard->trainer>=0.0.32->-r requirements.txt (line 30)) (1.1.0)
# Requirement already satisfied: markdown>=2.6.8 in /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from tensorboard->trainer>=0.0.32->-r requirements.txt (line 30)) (3.5.1)
# Requirement already satisfied: protobuf<4.24,>=3.19.6 in /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from tensorboard->trainer>=0.0.32->-r requirements.txt (line 30)) (4.23.4)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from tensorboard->trainer>=0.0.32->-r requirements.txt (line 30)) (0.7.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard->trainer>=0.0.32->-r requirements.txt (line 30)) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard->trainer>=0.0.32->-r requirements.txt (line 30)) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard->trainer>=0.0.32->-r requirements.txt (line 30)) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard->trainer>=0.0.32->-r requirements.txt (line 30)) (1.3.1)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->trainer>=0.0.32->-r requirements.txt (line 30)) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard->trainer>=0.0.32->-r requirements.txt (line 30)) (3.2.2)
# Downloading Cython-3.0.6-cp311-cp311-macosx_10_9_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 11.5 MB/s eta 0:00:00a 0:00:01
# Downloading torchaudio-2.1.1-cp311-cp311-macosx_10_13_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 11.9 MB/s eta 0:00:0000:0100:01
# Downloading librosa-0.10.1-py3-none-any.whl (253 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.7/253.7 kB 10.3 MB/s eta 0:00:00
# Downloading aiohttp-3.9.1-cp311-cp311-macosx_10_9_x86_64.whl (397 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 397.6/397.6 kB 9.7 MB/s eta 0:00:00:00:01
# Downloading trainer-0.0.32-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.0/51.0 kB 5.0 MB/s eta 0:00:00
# Downloading pypinyin-0.49.0-py2.py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 12.6 MB/s eta 0:00:0000:0100:01
# Downloading einops-0.7.0-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 3.8 MB/s eta 0:00:00
# Downloading transformers-4.35.2-py3-none-any.whl (7.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 13.5 MB/s eta 0:00:0000:0100:01
# Downloading Unidecode-1.3.7-py3-none-any.whl (235 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.5/235.5 kB 8.3 MB/s eta 0:00:00
# Downloading num2words-0.5.13-py3-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.3/143.3 kB 11.2 MB/s eta 0:00:00
# Downloading spacy-3.7.2-cp311-cp311-macosx_10_9_x86_64.whl (6.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 14.1 MB/s eta 0:00:0000:0100:01
# Downloading catalogue-2.0.10-py3-none-any.whl (17 kB)
# Downloading cymem-2.0.8-cp311-cp311-macosx_10_9_x86_64.whl (41 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.9/41.9 kB 3.8 MB/s eta 0:00:00
# Downloading frozenlist-1.4.0-cp311-cp311-macosx_10_9_x86_64.whl (47 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.7/47.7 kB 4.2 MB/s eta 0:00:00
# Downloading huggingface_hub-0.19.4-py3-none-any.whl (311 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.7/311.7 kB 11.5 MB/s eta 0:00:00
# Downloading murmurhash-1.0.10-cp311-cp311-macosx_10_9_x86_64.whl (26 kB)
# Downloading preshed-3.0.9-cp311-cp311-macosx_10_9_x86_64.whl (132 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.0/133.0 kB 8.2 MB/s eta 0:00:00
# Downloading pynndescent-0.5.11-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 kB 5.3 MB/s eta 0:00:00
# Downloading pytz-2023.3.post1-py2.py3-none-any.whl (502 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 502.5/502.5 kB 12.3 MB/s eta 0:00:0000:01
# Downloading safetensors-0.4.0-cp311-cp311-macosx_10_7_x86_64.whl (439 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 439.2/439.2 kB 14.5 MB/s eta 0:00:00
# Downloading smart_open-6.4.0-py3-none-any.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 5.4 MB/s eta 0:00:00
# Downloading spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# Downloading srsly-2.4.8-cp311-cp311-macosx_10_9_x86_64.whl (490 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 490.0/490.0 kB 11.4 MB/s eta 0:00:0000:01
# Downloading SudachiDict_core-20230927-py3-none-any.whl (71.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.7/71.7 MB 9.7 MB/s eta 0:00:00:00:010:01m
# Downloading thinc-8.2.1-cp311-cp311-macosx_10_9_x86_64.whl (859 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 859.8/859.8 kB 12.0 MB/s eta 0:00:0000:0100:01
# Downloading tokenizers-0.15.0-cp311-cp311-macosx_10_7_x86_64.whl (2.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 12.0 MB/s eta 0:00:00a 0:00:01
# Downloading wasabi-1.1.2-py3-none-any.whl (27 kB)
# Downloading weasel-0.3.4-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 kB 4.8 MB/s eta 0:00:00
# Downloading yarl-1.9.3-cp311-cp311-macosx_10_9_x86_64.whl (82 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.4/82.4 kB 5.6 MB/s eta 0:00:00
# Downloading blis-0.7.11-cp311-cp311-macosx_10_9_x86_64.whl (6.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 12.7 MB/s eta 0:00:0000:0100:01
# Downloading cloudpathlib-0.16.0-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.0/45.0 kB 4.8 MB/s eta 0:00:00
# Downloading confection-0.1.4-py3-none-any.whl (35 kB)
# Downloading tzlocal-5.2-py3-none-any.whl (17 kB)
# Building wheels for collected packages: gruut, umap-learn, jieba, bnnumerizer, bnunicodenormalizer, encodec, docopt, gruut-ipa, gruut_lang_de, gruut_lang_en, gruut_lang_es, gruut_lang_fr
#   Building wheel for gruut (setup.py) ... done
#   Created wheel for gruut: filename=gruut-2.2.3-py3-none-any.whl size=75793 sha256=bc62d5ef4d4117b13194904efb391e1c0b105e797fc935bb28805321aa6ac41b
#   Stored in directory: /Users/francisohara/Library/Caches/pip/wheels/1f/a0/bc/4dacab52579ab464cffafbe7a8e3792dd36ad9ac288b264843
#   Building wheel for umap-learn (setup.py) ... done
#   Created wheel for umap-learn: filename=umap_learn-0.5.5-py3-none-any.whl size=86832 sha256=c105b5a5b0480602155af2a636cff302b5824ed5575864bed025ce104c0e52b8
#   Stored in directory: /Users/francisohara/Library/Caches/pip/wheels/de/07/2e/814a6ee82e37528f2044a609a431028375b149bc31f03c0e27
#   Building wheel for jieba (setup.py) ... done
#   Created wheel for jieba: filename=jieba-0.42.1-py3-none-any.whl size=19314458 sha256=63957f06476d526b2ad87aa577ff8d1193eec974159247048319fc6a54c65aab
#   Stored in directory: /Users/francisohara/Library/Caches/pip/wheels/ac/60/cf/538a1f183409caf1fc136b5d2c2dee329001ef6da2c5084bef
#   Building wheel for bnnumerizer (setup.py) ... done
#   Created wheel for bnnumerizer: filename=bnnumerizer-0.0.2-py3-none-any.whl size=5259 sha256=082846fa80cbe7559ab835c75c6e0ba56fe39ef792a06b2fbbcd2c07ad4fbf5e
#   Stored in directory: /Users/francisohara/Library/Caches/pip/wheels/9e/b9/e3/4145416693824818c0b931988a692676ecd4bbf2ea41d1eedd
#   Building wheel for bnunicodenormalizer (setup.py) ... done
#   Created wheel for bnunicodenormalizer: filename=bnunicodenormalizer-0.1.6-py3-none-any.whl size=22779 sha256=fe87ee978ea8038e4b529c49313675217d3ab435d574e8daf84760cae425f059
#   Stored in directory: /Users/francisohara/Library/Caches/pip/wheels/9e/ea/56/34bd9fbd2e2b0a0166461fb78518deebe2d6f8e8e028a2be7c
#   Building wheel for encodec (setup.py) ... done
#   Created wheel for encodec: filename=encodec-0.1.1-py3-none-any.whl size=45760 sha256=0abf7d74cf394cfdb014a25ab8a66e16b862b49eb0b6c680126ee88d739b6a81
#   Stored in directory: /Users/francisohara/Library/Caches/pip/wheels/b4/a4/88/480018a664e58ca7ce6708759193ee51b017b3b72aa3df8a85
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13705 sha256=cc2ace1a2b79d1ab74d5e50bffc7f1de9fe5a22452182626a6e209d92c880c5b
#   Stored in directory: /Users/francisohara/Library/Caches/pip/wheels/1a/b0/8c/4b75c4116c31f83c8f9f047231251e13cc74481cca4a78a9ce
#   Building wheel for gruut-ipa (setup.py) ... done
#   Created wheel for gruut-ipa: filename=gruut_ipa-0.13.0-py3-none-any.whl size=104871 sha256=bdd29efb8317a3939a6d02ce516c000117efa4473af24701f2d81057d91b4e30
#   Stored in directory: /Users/francisohara/Library/Caches/pip/wheels/c7/10/89/a5908dd7a9a032229684b7679396785e19f816667f788087fb
#   Building wheel for gruut_lang_de (setup.py) ... done
#   Created wheel for gruut_lang_de: filename=gruut_lang_de-2.0.0-py3-none-any.whl size=18498181 sha256=22fbbadb9d26dff2d22bb2d6b345f44daf80ca4b7abde1abbc37a798f9977e94
#   Stored in directory: /Users/francisohara/Library/Caches/pip/wheels/c4/ad/f3/eecf61483881d7a8a83ece48eeaf9ee3ad202ccb530863d9e5
#   Building wheel for gruut_lang_en (setup.py) ... done
#   Created wheel for gruut_lang_en: filename=gruut_lang_en-2.0.0-py3-none-any.whl size=15297179 sha256=fce1555d3894c627acbcfc49409bdfc936963082eaf15e74bc75c130e0e31fb9
#   Stored in directory: /Users/francisohara/Library/Caches/pip/wheels/e2/78/bd/1d87e79fe8b770d31295d9340cc05bc16ddb892d0bae94a58b
#   Building wheel for gruut_lang_es (setup.py) ... done
#   Created wheel for gruut_lang_es: filename=gruut_lang_es-2.0.0-py3-none-any.whl size=32173797 sha256=311a2d5b334fd10077f870a8b86e0c88882386cbd32f7280dbc660993a393a23
#   Stored in directory: /Users/francisohara/Library/Caches/pip/wheels/7e/80/02/78d177dbdf2925c013cb935a430e98930b399e817c83586bbc
#   Building wheel for gruut_lang_fr (setup.py) ... done
#   Created wheel for gruut_lang_fr: filename=gruut_lang_fr-2.0.2-py3-none-any.whl size=10968767 sha256=5847c167cdd1913202d1b7d6c09cf6166873b84361fd48488ab9ab4b4bb6ba80
#   Stored in directory: /Users/francisohara/Library/Caches/pip/wheels/e0/e7/a0/7c416a3eeaa94ca71bf7bcbc6289cced2263d8ba35e82444bb
# Successfully built gruut umap-learn jieba bnnumerizer bnunicodenormalizer encodec docopt gruut-ipa gruut_lang_de gruut_lang_en gruut_lang_es gruut_lang_fr
# Installing collected packages: sudachipy, pytz, python-crfsuite, jieba, jamo, hangul_romanize, gruut_lang_fr, gruut_lang_es, gruut_lang_en, gruut_lang_de, docopt, cymem, bnunicodenormalizer, bnnumerizer, bangla, wasabi, unidecode, tzlocal, typer, sudachidict-core, spacy-loggers, spacy-legacy, smart-open, safetensors, pysbd, pypinyin, num2words, nltk, networkx, murmurhash, multidict, langcodes, jsonlines, gruut-ipa, frozenlist, einops, cython, coqpit, cloudpathlib, catalogue, blis, anyascii, yarl, srsly, preshed, pandas, huggingface-hub, g2pkk, dateparser, aiosignal, torchaudio, tokenizers, pynndescent, librosa, gruut, confection, aiohttp, weasel, umap-learn, transformers, thinc, encodec, trainer, spacy
#   Attempting uninstall: unidecode
#     Found existing installation: Unidecode 1.3.7
#     Uninstalling Unidecode-1.3.7:
#       Successfully uninstalled Unidecode-1.3.7
#   Attempting uninstall: networkx
#     Found existing installation: networkx 3.2.1
#     Uninstalling networkx-3.2.1:
#       Successfully uninstalled networkx-3.2.1
#   Attempting uninstall: librosa
#     Found existing installation: librosa 0.9.1
#     Uninstalling librosa-0.9.1:
#       Successfully uninstalled librosa-0.9.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tts 0.0.3+c7296b3 requires librosa==0.6.2, but you have librosa 0.10.1 which is incompatible.
# tts 0.0.3+c7296b3 requires unidecode==0.4.20, but you have unidecode 1.3.7 which is incompatible.
# Successfully installed aiohttp-3.9.1 aiosignal-1.3.1 anyascii-0.3.2 bangla-0.0.2 blis-0.7.11 bnnumerizer-0.0.2 bnunicodenormalizer-0.1.6 catalogue-2.0.10 cloudpathlib-0.16.0 confection-0.1.4 coqpit-0.0.17 cymem-2.0.8 cython-3.0.6 dateparser-1.1.8 docopt-0.6.2 einops-0.7.0 encodec-0.1.1 frozenlist-1.4.0 g2pkk-0.1.2 gruut-2.2.3 gruut-ipa-0.13.0 gruut_lang_de-2.0.0 gruut_lang_en-2.0.0 gruut_lang_es-2.0.0 gruut_lang_fr-2.0.2 hangul_romanize-0.1.0 huggingface-hub-0.19.4 jamo-0.4.1 jieba-0.42.1 jsonlines-1.2.0 langcodes-3.3.0 librosa-0.10.1 multidict-6.0.4 murmurhash-1.0.10 networkx-2.8.8 nltk-3.8.1 num2words-0.5.13 pandas-1.5.3 preshed-3.0.9 pynndescent-0.5.11 pypinyin-0.49.0 pysbd-0.3.4 python-crfsuite-0.9.9 pytz-2023.3.post1 safetensors-0.4.0 smart-open-6.4.0 spacy-3.7.2 spacy-legacy-3.0.12 spacy-loggers-1.0.5 srsly-2.4.8 sudachidict-core-20230927 sudachipy-0.6.7 thinc-8.2.1 tokenizers-0.15.0 torchaudio-2.1.1 trainer-0.0.32 transformers-4.35.2 typer-0.9.0 tzlocal-5.2 umap-learn-0.5.5 unidecode-1.3.7 wasabi-1.1.2 weasel-0.3.4 yarl-1.9.3
# Compiling TTS/tts/utils/monotonic_align/core.pyx because it changed.
# [1/1] Cythonizing TTS/tts/utils/monotonic_align/core.pyx
# performance hint: TTS/tts/utils/monotonic_align/core.pyx:11:5: Exception check on 'maximum_path_each' will always require the GIL to be acquired.
# Possible solutions:
# 	1. Declare the function as 'noexcept' if you control the definition and you're sure you don't want the function to raise exceptions.
# 	2. Use an 'int' return type on the function to allow an error code to be returned.
# performance hint: TTS/tts/utils/monotonic_align/core.pyx:42:6: Exception check on 'maximum_path_c' will always require the GIL to be acquired.
# Possible solutions:
# 	1. Declare the function as 'noexcept' if you control the definition and you're sure you don't want the function to raise exceptions.
# 	2. Use an 'int' return type on the function to allow an error code to be returned.
# performance hint: TTS/tts/utils/monotonic_align/core.pyx:47:21: Exception check will always require the GIL to be acquired.
# Possible solutions:
# 	1. Declare the function as 'noexcept' if you control the definition and you're sure you don't want the function to raise exceptions.
# 	2. Use an 'int' return type on the function to allow an error code to be returned.
# running develop
# /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages/setuptools/command/develop.py:40: EasyInstallDeprecationWarning: easy_install command is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` and ``easy_install``.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://github.com/pypa/setuptools/issues/917 for details.
#         ********************************************************************************
#
# !!
#   easy_install.initialize_options(self)
# /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages/setuptools/_distutils/cmd.py:66: SetuptoolsDeprecationWarning: setup.py install is deprecated.
# !!
#
#         ********************************************************************************
#         Please avoid running ``setup.py`` directly.
#         Instead, use pypa/build, pypa/installer or other
#         standards-based tools.
#
#         See https://blog.ganssle.io/articles/2021/10/setup-py-deprecated.html for details.
#         ********************************************************************************
#
# !!
#   self.initialize_options()
# running egg_info
# creating TTS.egg-info
# writing TTS.egg-info/PKG-INFO
# writing dependency_links to TTS.egg-info/dependency_links.txt
# writing entry points to TTS.egg-info/entry_points.txt
# writing requirements to TTS.egg-info/requires.txt
# writing top-level names to TTS.egg-info/top_level.txt
# writing manifest file 'TTS.egg-info/SOURCES.txt'
# reading manifest file 'TTS.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no previously-included files matching '*' found under directory 'tests'
# no previously-included directories found matching 'tests*'
# adding license file 'LICENSE.txt'
# writing manifest file 'TTS.egg-info/SOURCES.txt'
# running build_ext
# building 'TTS.tts.utils.monotonic_align.core' extension
# creating build
# creating build/temp.macosx-13-x86_64-cpython-311
# creating build/temp.macosx-13-x86_64-cpython-311/TTS
# creating build/temp.macosx-13-x86_64-cpython-311/TTS/tts
# creating build/temp.macosx-13-x86_64-cpython-311/TTS/tts/utils
# creating build/temp.macosx-13-x86_64-cpython-311/TTS/tts/utils/monotonic_align
# clang -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -isysroot /Library/Developer/CommandLineTools/SDKs/MacOSX13.sdk -I/Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages/numpy/core/include -I/Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/include -I/usr/local/opt/python@3.11/Frameworks/Python.framework/Versions/3.11/include/python3.11 -c TTS/tts/utils/monotonic_align/core.c -o build/temp.macosx-13-x86_64-cpython-311/TTS/tts/utils/monotonic_align/core.o
# In file included from TTS/tts/utils/monotonic_align/core.c:1205:
# ...
# Searching for pynndescent==0.5.11
# Best match: pynndescent 0.5.11
# Adding pynndescent 0.5.11 to easy-install.pth file
#
# Using /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages
# Searching for blinker==1.7.0
# Best match: blinker 1.7.0
# Adding blinker 1.7.0 to easy-install.pth file
#
# Using /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages
# Searching for itsdangerous==2.1.2
# Best match: itsdangerous 2.1.2
# Adding itsdangerous 2.1.2 to easy-install.pth file
#
# Using /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages
# Searching for werkzeug==3.0.1
# Best match: werkzeug 3.0.1
# Adding werkzeug 3.0.1 to easy-install.pth file
#
# Using /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages
# Searching for aiosignal==1.3.1
# Best match: aiosignal 1.3.1
# Adding aiosignal 1.3.1 to easy-install.pth file
#
# Using /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages
# Searching for frozenlist==1.4.0
# Best match: frozenlist 1.4.0
# Adding frozenlist 1.4.0 to easy-install.pth file
#
# Using /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages
# Searching for yarl==1.9.3
# Best match: yarl 1.9.3
# Adding yarl 1.9.3 to easy-install.pth file
#
# Using /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages
# Searching for multidict==6.0.4
# Best match: multidict 6.0.4
# Adding multidict 6.0.4 to easy-install.pth file
#
# Using /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages
# Searching for attrs==23.1.0
# Best match: attrs 23.1.0
# Adding attrs 23.1.0 to easy-install.pth file
#
# Using /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages
# Searching for typing-extensions==4.8.0
# Best match: typing-extensions 4.8.0
# Adding typing-extensions 4.8.0 to easy-install.pth file
#
# Using /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages
# Searching for threadpoolctl==3.2.0
# Best match: threadpoolctl 3.2.0
# Adding threadpoolctl 3.2.0 to easy-install.pth file
#
# Using /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages
# Searching for msgpack==1.0.7
# Best match: msgpack 1.0.7
# Adding msgpack 1.0.7 to easy-install.pth file
#
# Using /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages
# Searching for lazy-loader==0.3
# Best match: lazy-loader 0.3
# Adding lazy-loader 0.3 to easy-install.pth file
#
# Using /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages
# Searching for soxr==0.3.7
# Best match: soxr 0.3.7
# Adding soxr 0.3.7 to easy-install.pth file
#
# Using /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages
# Searching for pooch==1.8.0
# Best match: pooch 1.8.0
# Adding pooch 1.8.0 to easy-install.pth file
#
# Using /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages
# Searching for decorator==5.1.1
# Best match: decorator 5.1.1
# Adding decorator 5.1.1 to easy-install.pth file
#
# Using /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages
# Searching for audioread==3.0.1
# Best match: audioread 3.0.1
# Adding audioread 3.0.1 to easy-install.pth file
#
# Using /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages
# Searching for cffi==1.16.0
# Best match: cffi 1.16.0
# Adding cffi 1.16.0 to easy-install.pth file
#
# Using /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages
# Searching for sympy==1.12
# Best match: sympy 1.12
# Adding sympy 1.12 to easy-install.pth file
# Installing isympy script to /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/bin
#
# Using /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages
# Searching for MarkupSafe==2.1.3
# Best match: MarkupSafe 2.1.3
# Adding MarkupSafe 2.1.3 to easy-install.pth file
#
# Using /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages
# Searching for pydantic-core==2.14.5
# Best match: pydantic-core 2.14.5
# Adding pydantic-core 2.14.5 to easy-install.pth file
#
# Using /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages
# Searching for annotated-types==0.6.0
# Best match: annotated-types 0.6.0
# Adding annotated-types 0.6.0 to easy-install.pth file
#
# Using /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages
# Searching for certifi==2023.11.17
# Best match: certifi 2023.11.17
# Adding certifi 2023.11.17 to easy-install.pth file
#
# Using /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages
# Searching for urllib3==2.1.0
# Best match: urllib3 2.1.0
# Adding urllib3 2.1.0 to easy-install.pth file
#
# Using /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages
# Searching for idna==3.6
# Best match: idna 3.6
# Adding idna 3.6 to easy-install.pth file
#
# Using /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages
# Searching for charset-normalizer==3.3.2
# Best match: charset-normalizer 3.3.2
# Adding charset-normalizer 3.3.2 to easy-install.pth file
# Installing normalizer script to /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/bin
#
# Using /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages
# Searching for cloudpathlib==0.16.0
# Best match: cloudpathlib 0.16.0
# Adding cloudpathlib 0.16.0 to easy-install.pth file
#
# Using /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages
# Searching for confection==0.1.4
# Best match: confection 0.1.4
# Adding confection 0.1.4 to easy-install.pth file
#
# Using /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages
# Searching for blis==0.7.11
# Best match: blis 0.7.11
# Adding blis 0.7.11 to easy-install.pth file
#
# Using /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages
# Searching for six==1.16.0
# Best match: six 1.16.0
# Adding six 1.16.0 to easy-install.pth file
#
# Using /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages
# Searching for tzlocal==5.2
# Best match: tzlocal 5.2
# Adding tzlocal 5.2 to easy-install.pth file
#
# Using /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages
# Searching for tensorboard-data-server==0.7.2
# Best match: tensorboard-data-server 0.7.2
# Adding tensorboard-data-server 0.7.2 to easy-install.pth file
#
# Using /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages
# Searching for protobuf==4.23.4
# Best match: protobuf 4.23.4
# Adding protobuf 4.23.4 to easy-install.pth file
#
# Using /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages
# Searching for Markdown==3.5.1
# Best match: Markdown 3.5.1
# Adding Markdown 3.5.1 to easy-install.pth file
# Installing markdown_py script to /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/bin
#
# Using /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages
# Searching for google-auth-oauthlib==1.1.0
# Best match: google-auth-oauthlib 1.1.0
# Adding google-auth-oauthlib 1.1.0 to easy-install.pth file
# Installing google-oauthlib-tool script to /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/bin
#
# Using /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages
# Searching for google-auth==2.23.4
# Best match: google-auth 2.23.4
# Adding google-auth 2.23.4 to easy-install.pth file
#
# Using /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages
# Searching for grpcio==1.59.3
# Best match: grpcio 1.59.3
# Adding grpcio 1.59.3 to easy-install.pth file
#
# Using /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages
# Searching for absl-py==2.0.0
# Best match: absl-py 2.0.0
# Adding absl-py 2.0.0 to easy-install.pth file
#
# Using /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages
# Searching for platformdirs==4.0.0
# Best match: platformdirs 4.0.0
# Adding platformdirs 4.0.0 to easy-install.pth file
#
# Using /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages
# Searching for pycparser==2.21
# Best match: pycparser 2.21
# Adding pycparser 2.21 to easy-install.pth file
#
# Using /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages
# Searching for mpmath==1.3.0
# Best match: mpmath 1.3.0
# Adding mpmath 1.3.0 to easy-install.pth file
#
# Using /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages
# Searching for requests-oauthlib==1.3.1
# Best match: requests-oauthlib 1.3.1
# Adding requests-oauthlib 1.3.1 to easy-install.pth file
#
# Using /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages
# Searching for rsa==4.9
# Best match: rsa 4.9
# Adding rsa 4.9 to easy-install.pth file
# Installing pyrsa-decrypt script to /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/bin
# Installing pyrsa-encrypt script to /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/bin
# Installing pyrsa-keygen script to /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/bin
# Installing pyrsa-priv2pub script to /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/bin
# Installing pyrsa-sign script to /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/bin
# Installing pyrsa-verify script to /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/bin
#
# Using /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages
# Searching for pyasn1-modules==0.3.0
# Best match: pyasn1-modules 0.3.0
# Adding pyasn1-modules 0.3.0 to easy-install.pth file
#
# Using /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages
# Searching for cachetools==5.3.2
# Best match: cachetools 5.3.2
# Adding cachetools 5.3.2 to easy-install.pth file
#
# Using /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages
# Searching for oauthlib==3.2.2
# Best match: oauthlib 3.2.2
# Adding oauthlib 3.2.2 to easy-install.pth file
#
# Using /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages
# Searching for pyasn1==0.5.1
# Best match: pyasn1 0.5.1
# Adding pyasn1 0.5.1 to easy-install.pth file
#
# Using /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages
# Finished processing dependencies for TTS==0.21.1
# DEPRECATION: Loading egg at /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages/attrdict-2.0.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages/TTS-0.0.3+c7296b3-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages/Unidecode-0.04.20-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages/librosa-0.6.2-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages/resampy-0.4.2-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# ERROR: Could not find a version that satisfies the requirement tensorflow==2.3.0rc0 (from versions: 2.12.0rc0, 2.12.0rc1, 2.12.0, 2.12.1, 2.13.0rc0, 2.13.0rc1, 2.13.0rc2, 2.13.0, 2.13.1, 2.14.0rc0, 2.14.0rc1, 2.14.0, 2.14.1, 2.15.0rc0, 2.15.0rc1, 2.15.0)
# ERROR: No matching distribution found for tensorflow==2.3.0rc0
# /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow

# %%
# !pip install tensorflow
# Out:
# DEPRECATION: Loading egg at /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages/attrdict-2.0.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages/TTS-0.0.3+c7296b3-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages/Unidecode-0.04.20-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages/librosa-0.6.2-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages/resampy-0.4.2-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# Requirement already satisfied: tensorflow in ./venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (2.15.0)
# Requirement already satisfied: absl-py>=1.0.0 in ./venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from tensorflow) (2.0.0)
# Requirement already satisfied: astunparse>=1.6.0 in ./venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in ./venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from tensorflow) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in ./venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in ./venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in ./venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from tensorflow) (3.10.0)
# Requirement already satisfied: libclang>=13.0.0 in ./venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from tensorflow) (16.0.6)
# Requirement already satisfied: ml-dtypes~=0.2.0 in ./venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in ./venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from tensorflow) (1.26.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in ./venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: packaging in ./venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from tensorflow) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in ./venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from tensorflow) (4.23.4)
# Requirement already satisfied: setuptools in ./venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from tensorflow) (68.2.0)
# Requirement already satisfied: six>=1.12.0 in ./venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in ./venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from tensorflow) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in ./venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from tensorflow) (4.8.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in ./venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in ./venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from tensorflow) (0.34.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in ./venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from tensorflow) (1.59.3)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in ./venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from tensorflow) (2.15.1)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in ./venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in ./venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in ./venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from astunparse>=1.6.0->tensorflow) (0.41.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in ./venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.23.4)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in ./venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (1.1.0)
# Requirement already satisfied: markdown>=2.6.8 in ./venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.5.1)
# Requirement already satisfied: requests<3,>=2.21.0 in ./venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in ./venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in ./venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from tensorboard<2.16,>=2.15->tensorflow) (3.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in ./venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in ./venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in ./venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in ./venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in ./venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow) (2023.11.17)
# Requirement already satisfied: MarkupSafe>=2.1.1 in ./venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in ./venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in ./venv_mozilla_tts_tensorflow/lib/python3.11/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow) (3.2.2)

# %% [markdown]
# # Model Conversion PyTorch -> TF -> TFLite

# %% [markdown]
# ## Converting PyTorch to Tensorflow

# %%
# !pip install fuzzywuzzy
# Out:
# DEPRECATION: Loading egg at /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages/attrdict-2.0.1-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages/TTS-0.0.3+c7296b3-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages/Unidecode-0.04.20-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages/librosa-0.6.2-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# DEPRECATION: Loading egg at /Users/francisohara/DataspellProjects/AI-Reader/notebooks/TTS/mozilla_tts_tensorflow/venv_mozilla_tts_tensorflow/lib/python3.11/site-packages/resampy-0.4.2-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# Collecting fuzzywuzzy
#   Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl (18 kB)
# Installing collected packages: fuzzywuzzy
# Successfully installed fuzzywuzzy-0.18.0

# %%
# convert TTS model to Tensorflow
# !python ./content/TTS/tf/convert_tacotron2_torch_to_tf.py --config_path config.json --torch_model_path tts_model.pth.tar --output_path tts_model_tf.pkl
# Out:
# /usr/local/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/Resources/Python.app/Contents/MacOS/Python: can't open file '/content/TTS/tf/convert_tacotron2_torch_to_tf.py': [Errno 2] No such file or directory

# %%
# convert Vocoder model to Tensorflow
# !python /content/TTS/vocoder/tf/convert_melgan_torch_to_tf.py --config_path config_vocoder.json --torch_model_path vocoder_model.pth.tar --output_path vocoder_model_tf.pkl
# Out:
# 2020-07-14 15:35:46.508612: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# /usr/local/lib/python3.6/dist-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')
#  > Generator Model: multiband_melgan_generator
#  > Generator Model: multiband_melgan_generator
# 2020-07-14 15:35:50.941316: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2020-07-14 15:35:50.945075: E tensorflow/stream_executor/cuda/cuda_driver.cc:314] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2020-07-14 15:35:50.945116: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (b05eeb264940): /proc/driver/nvidia/version does not exist
# 2020-07-14 15:35:50.945411: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2020-07-14 15:35:50.950804: I tensorflow/core/platform/profile_utils/cpu_utils.cc:104] CPU Frequency: 2300000000 Hz
# 2020-07-14 15:35:50.951057: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x885bd40 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-07-14 15:35:50.951092: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
#  > Passing weights from Torch to TF ...
#  | > 1/kernel:0 <-- layers.1.weight
#  | > 1/bias:0 <-- layers.1.bias
#  | > 3/kernel:0 <-- layers.3.weight
#  | > 3/bias:0 <-- layers.3.bias
#  | > layers.4/blocks.0.2/kernel:0 <-- layers.4.blocks.0.2.weight
#  | > layers.4/blocks.0.2/bias:0 <-- layers.4.blocks.0.2.bias
#  | > layers.4/blocks.0.4/kernel:0 <-- layers.4.blocks.0.4.weight
#  | > layers.4/blocks.0.4/bias:0 <-- layers.4.blocks.0.4.bias
#  | > layers.4/blocks.1.2/kernel:0 <-- layers.4.blocks.1.2.weight
#  | > layers.4/blocks.1.2/bias:0 <-- layers.4.blocks.1.2.bias
#  | > layers.4/blocks.1.4/kernel:0 <-- layers.4.blocks.1.4.weight
#  | > layers.4/blocks.1.4/bias:0 <-- layers.4.blocks.1.4.bias
#  | > layers.4/blocks.2.2/kernel:0 <-- layers.4.blocks.2.2.weight
#  | > layers.4/blocks.2.2/bias:0 <-- layers.4.blocks.2.2.bias
#  | > layers.4/blocks.2.4/kernel:0 <-- layers.4.blocks.2.4.weight
#  | > layers.4/blocks.2.4/bias:0 <-- layers.4.blocks.2.4.bias
#  | > layers.4/blocks.3.2/kernel:0 <-- layers.4.blocks.3.2.weight
#  | > layers.4/blocks.3.2/bias:0 <-- layers.4.blocks.3.2.bias
#  | > layers.4/blocks.3.4/kernel:0 <-- layers.4.blocks.3.4.weight
#  | > layers.4/blocks.3.4/bias:0 <-- layers.4.blocks.3.4.bias
#  | > layers.4/shortcuts.0/kernel:0 <-- layers.4.shortcuts.0.weight
#  | > layers.4/shortcuts.0/bias:0 <-- layers.4.shortcuts.0.bias
#  | > layers.4/shortcuts.1/kernel:0 <-- layers.4.shortcuts.1.weight
#  | > layers.4/shortcuts.1/bias:0 <-- layers.4.shortcuts.1.bias
#  | > layers.4/shortcuts.2/kernel:0 <-- layers.4.shortcuts.2.weight
#  | > layers.4/shortcuts.2/bias:0 <-- layers.4.shortcuts.2.bias
#  | > layers.4/shortcuts.3/kernel:0 <-- layers.4.shortcuts.3.weight
#  | > layers.4/shortcuts.3/bias:0 <-- layers.4.shortcuts.3.bias
#  | > 6/kernel:0 <-- layers.6.weight
#  | > 6/bias:0 <-- layers.6.bias
#  | > layers.7/blocks.0.2/kernel:0 <-- layers.7.blocks.0.2.weight
#  | > layers.7/blocks.0.2/bias:0 <-- layers.7.blocks.0.2.bias
#  | > layers.7/blocks.0.4/kernel:0 <-- layers.7.blocks.0.4.weight
#  | > layers.7/blocks.0.4/bias:0 <-- layers.7.blocks.0.4.bias
#  | > layers.7/blocks.1.2/kernel:0 <-- layers.7.blocks.1.2.weight
#  | > layers.7/blocks.1.2/bias:0 <-- layers.7.blocks.1.2.bias
#  | > layers.7/blocks.1.4/kernel:0 <-- layers.7.blocks.1.4.weight
#  | > layers.7/blocks.1.4/bias:0 <-- layers.7.blocks.1.4.bias
#  | > layers.7/blocks.2.2/kernel:0 <-- layers.7.blocks.2.2.weight
#  | > layers.7/blocks.2.2/bias:0 <-- layers.7.blocks.2.2.bias
#  | > layers.7/blocks.2.4/kernel:0 <-- layers.7.blocks.2.4.weight
#  | > layers.7/blocks.2.4/bias:0 <-- layers.7.blocks.2.4.bias
#  | > layers.7/blocks.3.2/kernel:0 <-- layers.7.blocks.3.2.weight
#  | > layers.7/blocks.3.2/bias:0 <-- layers.7.blocks.3.2.bias
#  | > layers.7/blocks.3.4/kernel:0 <-- layers.7.blocks.3.4.weight
#  | > layers.7/blocks.3.4/bias:0 <-- layers.7.blocks.3.4.bias
#  | > layers.7/shortcuts.0/kernel:0 <-- layers.7.shortcuts.0.weight
#  | > layers.7/shortcuts.0/bias:0 <-- layers.7.shortcuts.0.bias
#  | > layers.7/shortcuts.1/kernel:0 <-- layers.7.shortcuts.1.weight
#  | > layers.7/shortcuts.1/bias:0 <-- layers.7.shortcuts.1.bias
#  | > layers.7/shortcuts.2/kernel:0 <-- layers.7.shortcuts.2.weight
#  | > layers.7/shortcuts.2/bias:0 <-- layers.7.shortcuts.2.bias
#  | > layers.7/shortcuts.3/kernel:0 <-- layers.7.shortcuts.3.weight
#  | > layers.7/shortcuts.3/bias:0 <-- layers.7.shortcuts.3.bias
#  | > 9/kernel:0 <-- layers.9.weight
#  | > 9/bias:0 <-- layers.9.bias
#  | > layers.10/blocks.0.2/kernel:0 <-- layers.10.blocks.0.2.weight
#  | > layers.10/blocks.0.2/bias:0 <-- layers.10.blocks.0.2.bias
#  | > layers.10/blocks.0.4/kernel:0 <-- layers.10.blocks.0.4.weight
#  | > layers.10/blocks.0.4/bias:0 <-- layers.10.blocks.0.4.bias
#  | > layers.10/blocks.1.2/kernel:0 <-- layers.10.blocks.1.2.weight
#  | > layers.10/blocks.1.2/bias:0 <-- layers.10.blocks.1.2.bias
#  | > layers.10/blocks.1.4/kernel:0 <-- layers.10.blocks.1.4.weight
#  | > layers.10/blocks.1.4/bias:0 <-- layers.10.blocks.1.4.bias
#  | > layers.10/blocks.2.2/kernel:0 <-- layers.10.blocks.2.2.weight
#  | > layers.10/blocks.2.2/bias:0 <-- layers.10.blocks.2.2.bias
#  | > layers.10/blocks.2.4/kernel:0 <-- layers.10.blocks.2.4.weight
#  | > layers.10/blocks.2.4/bias:0 <-- layers.10.blocks.2.4.bias
#  | > layers.10/blocks.3.2/kernel:0 <-- layers.10.blocks.3.2.weight
#  | > layers.10/blocks.3.2/bias:0 <-- layers.10.blocks.3.2.bias
#  | > layers.10/blocks.3.4/kernel:0 <-- layers.10.blocks.3.4.weight
#  | > layers.10/blocks.3.4/bias:0 <-- layers.10.blocks.3.4.bias
#  | > layers.10/shortcuts.0/kernel:0 <-- layers.10.shortcuts.0.weight
#  | > layers.10/shortcuts.0/bias:0 <-- layers.10.shortcuts.0.bias
#  | > layers.10/shortcuts.1/kernel:0 <-- layers.10.shortcuts.1.weight
#  | > layers.10/shortcuts.1/bias:0 <-- layers.10.shortcuts.1.bias
#  | > layers.10/shortcuts.2/kernel:0 <-- layers.10.shortcuts.2.weight
#  | > layers.10/shortcuts.2/bias:0 <-- layers.10.shortcuts.2.bias
#  | > layers.10/shortcuts.3/kernel:0 <-- layers.10.shortcuts.3.weight
#  | > layers.10/shortcuts.3/bias:0 <-- layers.10.shortcuts.3.bias
#  | > layers.13/kernel:0 <-- layers.13.weight
#  | > layers.13/bias:0 <-- layers.13.bias
# 1 -> Conv1d(80, 384, kernel_size=(7,), stride=(1,)) vs <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fde4466d6a0>
# 2 -> LeakyReLU(negative_slope=0.2) vs <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fde4466def0>
# 3 -> ConvTranspose1d(384, 192, kernel_size=(16,), stride=(8,), padding=(4,)) vs <tensorflow.python.keras.layers.convolutional.Conv2DTranspose object at 0x7fde446021d0>
# 4 -> ResidualStack(
#   (blocks): ModuleList(
#     (0): Sequential(
#       (0): LeakyReLU(negative_slope=0.2)
#       (1): ReflectionPad1d((1, 1))
#       (2): Conv1d(192, 192, kernel_size=(3,), stride=(1,))
#       (3): LeakyReLU(negative_slope=0.2)
#       (4): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#     )
#     (1): Sequential(
#       (0): LeakyReLU(negative_slope=0.2)
#       (1): ReflectionPad1d((3, 3))
#       (2): Conv1d(192, 192, kernel_size=(3,), stride=(1,), dilation=(3,))
#       (3): LeakyReLU(negative_slope=0.2)
#       (4): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#     )
#     (2): Sequential(
#       (0): LeakyReLU(negative_slope=0.2)
#       (1): ReflectionPad1d((9, 9))
#       (2): Conv1d(192, 192, kernel_size=(3,), stride=(1,), dilation=(9,))
#       (3): LeakyReLU(negative_slope=0.2)
#       (4): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#     )
#     (3): Sequential(
#       (0): LeakyReLU(negative_slope=0.2)
#       (1): ReflectionPad1d((27, 27))
#       (2): Conv1d(192, 192, kernel_size=(3,), stride=(1,), dilation=(27,))
#       (3): LeakyReLU(negative_slope=0.2)
#       (4): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#     )
#   )
#   (shortcuts): ModuleList(
#     (0): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#     (1): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#     (2): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#     (3): Conv1d(192, 192, kernel_size=(1,), stride=(1,))
#   )
# ) vs <TTS.vocoder.tf.layers.melgan.ResidualStack object at 0x7fde446025f8>
# 5 -> LeakyReLU(negative_slope=0.2) vs <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fde4463d9e8>
# 6 -> ConvTranspose1d(192, 96, kernel_size=(8,), stride=(4,), padding=(2,)) vs <tensorflow.python.keras.layers.convolutional.Conv2DTranspose object at 0x7fde4463dcf8>
# 7 -> ResidualStack(
#   (blocks): ModuleList(
#     (0): Sequential(
#       (0): LeakyReLU(negative_slope=0.2)
#       (1): ReflectionPad1d((1, 1))
#       (2): Conv1d(96, 96, kernel_size=(3,), stride=(1,))
#       (3): LeakyReLU(negative_slope=0.2)
#       (4): Conv1d(96, 96, kernel_size=(1,), stride=(1,))
#     )
#     (1): Sequential(
#       (0): LeakyReLU(negative_slope=0.2)
#       (1): ReflectionPad1d((3, 3))
#       (2): Conv1d(96, 96, kernel_size=(3,), stride=(1,), dilation=(3,))
#       (3): LeakyReLU(negative_slope=0.2)
#       (4): Conv1d(96, 96, kernel_size=(1,), stride=(1,))
#     )
#     (2): Sequential(
#       (0): LeakyReLU(negative_slope=0.2)
#       (1): ReflectionPad1d((9, 9))
#       (2): Conv1d(96, 96, kernel_size=(3,), stride=(1,), dilation=(9,))
#       (3): LeakyReLU(negative_slope=0.2)
#       (4): Conv1d(96, 96, kernel_size=(1,), stride=(1,))
#     )
#     (3): Sequential(
#       (0): LeakyReLU(negative_slope=0.2)
#       (1): ReflectionPad1d((27, 27))
#       (2): Conv1d(96, 96, kernel_size=(3,), stride=(1,), dilation=(27,))
#       (3): LeakyReLU(negative_slope=0.2)
#       (4): Conv1d(96, 96, kernel_size=(1,), stride=(1,))
#     )
#   )
#   (shortcuts): ModuleList(
#     (0): Conv1d(96, 96, kernel_size=(1,), stride=(1,))
#     (1): Conv1d(96, 96, kernel_size=(1,), stride=(1,))
#     (2): Conv1d(96, 96, kernel_size=(1,), stride=(1,))
#     (3): Conv1d(96, 96, kernel_size=(1,), stride=(1,))
#   )
# ) vs <TTS.vocoder.tf.layers.melgan.ResidualStack object at 0x7fde445c80f0>
# 8 -> LeakyReLU(negative_slope=0.2) vs <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fde3e84de10>
# 9 -> ConvTranspose1d(96, 48, kernel_size=(4,), stride=(2,), padding=(1,)) vs <tensorflow.python.keras.layers.convolutional.Conv2DTranspose object at 0x7fde3e84dfd0>
# 10 -> ResidualStack(
#   (blocks): ModuleList(
#     (0): Sequential(
#       (0): LeakyReLU(negative_slope=0.2)
#       (1): ReflectionPad1d((1, 1))
#       (2): Conv1d(48, 48, kernel_size=(3,), stride=(1,))
#       (3): LeakyReLU(negative_slope=0.2)
#       (4): Conv1d(48, 48, kernel_size=(1,), stride=(1,))
#     )
#     (1): Sequential(
#       (0): LeakyReLU(negative_slope=0.2)
#       (1): ReflectionPad1d((3, 3))
#       (2): Conv1d(48, 48, kernel_size=(3,), stride=(1,), dilation=(3,))
#       (3): LeakyReLU(negative_slope=0.2)
#       (4): Conv1d(48, 48, kernel_size=(1,), stride=(1,))
#     )
#     (2): Sequential(
#       (0): LeakyReLU(negative_slope=0.2)
#       (1): ReflectionPad1d((9, 9))
#       (2): Conv1d(48, 48, kernel_size=(3,), stride=(1,), dilation=(9,))
#       (3): LeakyReLU(negative_slope=0.2)
#       (4): Conv1d(48, 48, kernel_size=(1,), stride=(1,))
#     )
#     (3): Sequential(
#       (0): LeakyReLU(negative_slope=0.2)
#       (1): ReflectionPad1d((27, 27))
#       (2): Conv1d(48, 48, kernel_size=(3,), stride=(1,), dilation=(27,))
#       (3): LeakyReLU(negative_slope=0.2)
#       (4): Conv1d(48, 48, kernel_size=(1,), stride=(1,))
#     )
#   )
#   (shortcuts): ModuleList(
#     (0): Conv1d(48, 48, kernel_size=(1,), stride=(1,))
#     (1): Conv1d(48, 48, kernel_size=(1,), stride=(1,))
#     (2): Conv1d(48, 48, kernel_size=(1,), stride=(1,))
#     (3): Conv1d(48, 48, kernel_size=(1,), stride=(1,))
#   )
# ) vs <TTS.vocoder.tf.layers.melgan.ResidualStack object at 0x7fde3e84a278>
# 11 -> LeakyReLU(negative_slope=0.2) vs <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7fde3e87c3c8>
# 12 -> ReflectionPad1d((3, 3)) vs <TTS.vocoder.tf.layers.melgan.ReflectionPad1d object at 0x7fde3e87c4e0>
# 13 -> Conv1d(48, 4, kernel_size=(7,), stride=(1,)) vs <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7fde3e87c630>
# 14 -> Tanh() vs <tensorflow.python.keras.layers.core.Activation object at 0x7fde3e87c898>
#  > Model conversion is successfully completed :).

# %% [markdown]
# ## Converting Tensorflow to TFLite

# %%
# convert TTS model to TFLite
# !python /content/TTS/tf/convert_tacotron2_tflite.py --config_path config.json --tf_model tts_model_tf.pkl --output_path tts_model.tflite
# Out:
# 2020-07-14 16:03:31.329598: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
#  > Using model: Tacotron2
# 2020-07-14 16:03:32.855337: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2020-07-14 16:03:32.858430: E tensorflow/stream_executor/cuda/cuda_driver.cc:314] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2020-07-14 16:03:32.858471: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (b05eeb264940): /proc/driver/nvidia/version does not exist
# 2020-07-14 16:03:32.858724: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2020-07-14 16:03:32.864269: I tensorflow/core/platform/profile_utils/cpu_utils.cc:104] CPU Frequency: 2300000000 Hz
# 2020-07-14 16:03:32.864495: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x3db76c0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-07-14 16:03:32.864528: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# (1, None, 80)
# (1, None, 80)
# (1, None, 80)
# 2020-07-14 16:03:48.010351: I tensorflow/core/grappler/devices.cc:69] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2020-07-14 16:03:48.010560: I tensorflow/core/grappler/clusters/single_machine.cc:356] Starting new session
# 2020-07-14 16:03:48.049106: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:816] Optimization results for grappler item: graph_to_optimize
# 2020-07-14 16:03:48.049185: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: Graph size after: 544 nodes (124), 587 edges (140), time = 7.357ms.
# 2020-07-14 16:03:48.049197: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: Graph size after: 544 nodes (0), 587 edges (0), time = 5.624ms.
# 2020-07-14 16:03:48.049205: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:816] Optimization results for grappler item: decoder_while_cond_5335
# 2020-07-14 16:03:48.049214: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.002ms.
# 2020-07-14 16:03:48.049245: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0ms.
# 2020-07-14 16:03:48.049260: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:816] Optimization results for grappler item: while_cond_4888
# 2020-07-14 16:03:48.049271: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# 2020-07-14 16:03:48.049282: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0ms.
# 2020-07-14 16:03:48.049302: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:816] Optimization results for grappler item: decoder_while_body_5336
# 2020-07-14 16:03:48.049311: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# 2020-07-14 16:03:48.049323: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0ms.
# 2020-07-14 16:03:48.049335: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:816] Optimization results for grappler item: while_body_4889
# 2020-07-14 16:03:48.049348: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# 2020-07-14 16:03:48.049360: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# 2020-07-14 16:03:48.049372: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:816] Optimization results for grappler item: while_cond_4448
# 2020-07-14 16:03:48.049385: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# 2020-07-14 16:03:48.049397: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0ms.
# 2020-07-14 16:03:48.049410: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:816] Optimization results for grappler item: while_body_4449
# 2020-07-14 16:03:48.049422: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.001ms.
# 2020-07-14 16:03:48.049434: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0ms.
# 2020-07-14 16:03:50.716853: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:313] Ignored output_format.
# 2020-07-14 16:03:50.716921: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:316] Ignored drop_control_dependency.
# 2020-07-14 16:03:52.190724: I tensorflow/lite/tools/optimize/quantize_weights.cc:203] Skipping quantization of tensor decoder/attention/inputs_layer/linear_layer/Tensordot/Shape that is not type float.
# 2020-07-14 16:03:52.190796: I tensorflow/lite/tools/optimize/quantize_weights.cc:203] Skipping quantization of tensor decoder/attention/inputs_layer/linear_layer/Tensordot/Shape that is not type float.
# 2020-07-14 16:03:52.190809: I tensorflow/lite/tools/optimize/quantize_weights.cc:220] Skipping quantization of tensor decoder/while11 because it has no allocated buffer.
# 2020-07-14 16:03:52.237981: I tensorflow/lite/tools/optimize/quantize_weights.cc:211] Skipping quantization of tensor arg6 because it has fewer than 1024 elements (512).
# 2020-07-14 16:03:52.242678: I tensorflow/lite/tools/optimize/quantize_weights.cc:211] Skipping quantization of tensor arg6 because it has fewer than 1024 elements (512).
# 2020-07-14 16:03:52.247295: I tensorflow/lite/tools/optimize/quantize_weights.cc:203] Skipping quantization of tensor decoder/while/attention/location_layer/location_dense/Tensordot/Shape that is not type float.
# 2020-07-14 16:03:52.247338: I tensorflow/lite/tools/optimize/quantize_weights.cc:203] Skipping quantization of tensor decoder/while/attention/location_layer/location_dense/Tensordot/Shape that is not type float.
# 2020-07-14 16:03:52.247354: I tensorflow/lite/tools/optimize/quantize_weights.cc:203] Skipping quantization of tensor decoder/while/attention/v/linear_layer/Tensordot/Shape that is not type float.
# 2020-07-14 16:03:52.247362: I tensorflow/lite/tools/optimize/quantize_weights.cc:203] Skipping quantization of tensor decoder/while/attention/v/linear_layer/Tensordot/Shape that is not type float.
# 2020-07-14 16:03:52.247376: I tensorflow/lite/tools/optimize/quantize_weights.cc:211] Skipping quantization of tensor decoder/while/attention/v/linear_layer/Tensordot/MatMul because it has fewer than 1024 elements (128).
# Tflite Model size is 28.666168212890625 MBs.

# %%
# convert Vocoder model to TFLite
# !python /content/TTS/vocoder/tf/convert_melgan_tflite.py --config_path config_vocoder.json --tf_model vocoder_model_tf.pkl --output_path vocoder_model.tflite
# Out:
# 2020-07-14 16:02:19.612450: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
#  > Generator Model: multiband_melgan_generator
# 2020-07-14 16:02:21.418525: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2020-07-14 16:02:21.421928: E tensorflow/stream_executor/cuda/cuda_driver.cc:314] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2020-07-14 16:02:21.421977: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (b05eeb264940): /proc/driver/nvidia/version does not exist
# 2020-07-14 16:02:21.422499: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2020-07-14 16:02:21.430885: I tensorflow/core/platform/profile_utils/cpu_utils.cc:104] CPU Frequency: 2300000000 Hz
# 2020-07-14 16:02:21.431116: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x5537dc0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-07-14 16:02:21.431153: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-07-14 16:02:23.557224: I tensorflow/core/grappler/devices.cc:69] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2020-07-14 16:02:23.557562: I tensorflow/core/grappler/clusters/single_machine.cc:356] Starting new session
# 2020-07-14 16:02:23.570784: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:816] Optimization results for grappler item: graph_to_optimize
# 2020-07-14 16:02:23.570835: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0.003ms.
# 2020-07-14 16:02:23.570847: I tensorflow/core/grappler/optimizers/meta_optimizer.cc:818]   function_optimizer: function_optimizer did nothing. time = 0ms.
# 2020-07-14 16:02:24.913709: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:313] Ignored output_format.
# 2020-07-14 16:02:24.913774: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:316] Ignored drop_control_dependency.
# Tflite Model size is 9.706932067871094 MBs.

# %% [markdown]
# # Run Inference with TFLite

# %%
def run_vocoder(mel_spec):
  vocoder_inputs = mel_spec[None, :, :]
  # get input and output details
  input_details = vocoder_model.get_input_details()
  # reshape input tensor for the new input shape
  vocoder_model.resize_tensor_input(input_details[0]['index'], vocoder_inputs.shape)
  vocoder_model.allocate_tensors()
  detail = input_details[0]
  vocoder_model.set_tensor(detail['index'], vocoder_inputs)
  # run the model
  vocoder_model.invoke()
  # collect outputs
  output_details = vocoder_model.get_output_details()
  waveform = vocoder_model.get_tensor(output_details[0]['index'])
  return waveform


def tts(model, text, CONFIG, p):
    t_1 = time.time()
    waveform, alignment, mel_spec, mel_postnet_spec, stop_tokens, inputs = synthesis(model, text, CONFIG, use_cuda, ap, speaker_id, style_wav=None,
                                                                             truncated=False, enable_eos_bos_chars=CONFIG.enable_eos_bos_chars,
                                                                             backend='tflite')
    waveform = run_vocoder(mel_postnet_spec.T)
    waveform = waveform[0, 0]
    rtf = (time.time() - t_1) / (len(waveform) / ap.sample_rate)
    tps = (time.time() - t_1) / len(waveform)
    print(waveform.shape)
    print(" > Run-time: {}".format(time.time() - t_1))
    print(" > Real-time factor: {}".format(rtf))
    print(" > Time per step: {}".format(tps))
    IPython.display.display(IPython.display.Audio(waveform, rate=CONFIG.audio['sample_rate']))
    return alignment, mel_postnet_spec, stop_tokens, waveform

# %% [markdown]
# ### Load TF Models

# %%
import os
import torch
import time
import IPython

from TTS.tf.utils.tflite import load_tflite_model
from TTS.tf.utils.io import load_checkpoint
from TTS.utils.io import load_config
from TTS.utils.text.symbols import symbols, phonemes
from TTS.utils.audio import AudioProcessor
from TTS.utils.synthesis import synthesis

# %%
# runtime settings
use_cuda = False

# %%
# model paths
TTS_MODEL = "tts_model.tflite"
TTS_CONFIG = "config.json"
VOCODER_MODEL = "vocoder_model.tflite"
VOCODER_CONFIG = "config_vocoder.json"

# %%
# load configs
TTS_CONFIG = load_config(TTS_CONFIG)
VOCODER_CONFIG = load_config(VOCODER_CONFIG)

# %%
# load the audio processor
ap = AudioProcessor(**TTS_CONFIG.audio)
# Out:
#  > Setting up Audio Processor...
#  | > sample_rate:22050
#  | > num_mels:80
#  | > min_level_db:-100
#  | > frame_shift_ms:None
#  | > frame_length_ms:None
#  | > ref_level_db:0
#  | > fft_size:1024
#  | > power:1.5
#  | > preemphasis:0.0
#  | > griffin_lim_iters:60
#  | > signal_norm:True
#  | > symmetric_norm:True
#  | > mel_fmin:50.0
#  | > mel_fmax:7600.0
#  | > spec_gain:1.0
#  | > stft_pad_mode:reflect
#  | > max_norm:4.0
#  | > clip_norm:True
#  | > do_trim_silence:True
#  | > trim_db:60
#  | > do_sound_norm:False
#  | > stats_path:./scale_stats.npy
#  | > hop_length:256
#  | > win_length:1024

# %%
# LOAD TTS MODEL
# multi speaker
speaker_id = None
speakers = []

# load the models
model = load_tflite_model(TTS_MODEL)
vocoder_model = load_tflite_model(VOCODER_MODEL)

# %% [markdown]
# ## Run Sample Sentence

# %%
sentence =  "Bill got in the habit of asking himself “Is that thought true?” and if he wasn’t absolutely certain it was, he just let it go."
align, spec, stop_tokens, wav = tts(model, sentence, TTS_CONFIG, ap)
# Out:
# (185856,)
#  > Run-time: 3.4360833168029785
#  > Real-time factor: 0.4076327362736641
#  > Time per step: 1.8486800570215405e-05
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
